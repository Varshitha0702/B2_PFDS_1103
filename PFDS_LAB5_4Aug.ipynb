# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshitha0702/B2_PFDS_1103/blob/main/PFDS_LAB5_4Aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Merge Product and Sales Datasets and Compute Aggregate Statistics Using pandas

# %% [markdown]
# ## Create/import two datasets (Products and Sales)

# %%
import numpy as np
import pandas as pd
p = pd.read_csv('/content/products.csv')
p.head()
# Out:
#   product_id product_name     category   price
# 0       P001    Product_1  Electronics  429.69
# 1       P002    Product_2     Clothing  982.09
# 2       P003    Product_3         Home  559.40
# 3       P004    Product_4         Home  942.28
# 4       P005    Product_5     Clothing  159.57

# %%
s=pd.read_csv('/content/sales.csv')
s.head()
# Out:
#   sale_id product_id  quantity   sale_date customer_id
# 0    S001       P013         4  2024-01-01         C36
# 1    S002       P003         3  2024-01-02          C7
# 2    S003       P018         6  2024-01-03          C4
# 3    S004       P010         3  2024-01-04         C42
# 4    S005       P020         9  2024-01-05         C35

# %% [markdown]
# ## Merge them using product_id.

# %%
merge=pd.merge(p,s,on='product_id')
merge.head()
# Out:
#   product_id product_name     category   price sale_id  quantity   sale_date  \
# 0       P001    Product_1  Electronics  429.69    S082         1  2024-03-22
# 1       P001    Product_1  Electronics  429.69    S092         8  2024-04-01
# 2       P002    Product_2     Clothing  982.09    S010         8  2024-01-10
# 3       P002    Product_2     Clothing  982.09    S037         7  2024-02-06
# 4       P002    Product_2     Clothing  982.09    S039         8  2024-02-08
#
#   customer_id
# 0         C43
# 1         C37
# 2         C11
# 3         C48
# 4          C4

# %% [markdown]
# ## Perform inner and outer joins.

# %%
inner_join=pd.merge(p,s,on='product_id',how='inner')
inner_join.head()
# Out:
#   product_id product_name     category   price sale_id  quantity   sale_date  \
# 0       P001    Product_1  Electronics  429.69    S082         1  2024-03-22
# 1       P001    Product_1  Electronics  429.69    S092         8  2024-04-01
# 2       P002    Product_2     Clothing  982.09    S010         8  2024-01-10
# 3       P002    Product_2     Clothing  982.09    S037         7  2024-02-06
# 4       P002    Product_2     Clothing  982.09    S039         8  2024-02-08
#
#   customer_id
# 0         C43
# 1         C37
# 2         C11
# 3         C48
# 4          C4

# %%
outer_join=pd.merge(p,s,on='product_id',how='outer')
outer_join.head()
# Out:
#   product_id product_name     category   price sale_id  quantity   sale_date  \
# 0       P001    Product_1  Electronics  429.69    S082       1.0  2024-03-22
# 1       P001    Product_1  Electronics  429.69    S092       8.0  2024-04-01
# 2       P002    Product_2     Clothing  982.09    S010       8.0  2024-01-10
# 3       P002    Product_2     Clothing  982.09    S037       7.0  2024-02-06
# 4       P002    Product_2     Clothing  982.09    S039       8.0  2024-02-08
#
#   customer_id
# 0         C43
# 1         C37
# 2         C11
# 3         C48
# 4          C4

# %% [markdown]
# ## Compute statistics like total revenue, average price, and product-wise sales

# %%
total_revenue=merge['price'].sum()
print("Total revenues:",total_revenue)
avergae_price=merge['price'].mean()
print("Average price:",avergae_price)
product_wise_sales=merge.groupby('product_id')['price'].sum()
print("Product wise sales:",product_wise_sales)
# Out:
# Total revenues: 52764.450000000004
# Average price: 527.6445
# Product wise sales: product_id
# P001     859.38
# P002    3928.36
# P003    3915.80
# P004    4711.40
# P005     638.28
# P006    5831.28
# P007     878.56
# P008    6750.87
# P009    2719.71
# P010     611.92
# P011    1851.36
# P012    3710.60
# P013    2783.92
# P014    1877.70
# P015    2679.25
# P016     831.88
# P017    2988.80
# P018    2043.93
# P019    2893.40
# P020     258.05
# Name: price, dtype: float64

# %% [markdown]
# ## Group by product category and find best-selling category

# %%
best_selling_category=merge.groupby('category')['price'].sum().idxmax()
print("Best selling category:",best_selling_category)
# Out:
# Best selling category: Home

# %% [markdown]
# # Merge Teachers and Courses Datasets and Compute Aggregate Statistics

# %% [markdown]
# ## Create two datasets (Teachers and Courses)

# %%
t=pd.read_csv('/content/teachers.csv')
t.head()
# Out:
#    teacher_id teacher_name department  experience_years
# 0           1    Teacher_1    English                 9
# 1           2    Teacher_2    English                11
# 2           3    Teacher_3    English                15
# 3           4    Teacher_4    English                24
# 4           5    Teacher_5    History                 6

# %%
c=pd.read_csv('/content/courses.csv')
c.head()
# Out:
#    course_id course_name  teacher_id  credits semester
# 0          1    Course_1           5        4   Spring
# 1          2    Course_2          74        2     Fall
# 2          3    Course_3          97        5     Fall
# 3          4    Course_4          38        4   Winter
# 4          5    Course_5          13        4     Fall

# %% [markdown]
# ## Merge on teacher_id.

# %%
merge=pd.merge(t,c,on='teacher_id')
merge.head()
# Out:
#    teacher_id teacher_name department  experience_years  course_id  \
# 0           1    Teacher_1    English                 9         66
# 1           1    Teacher_1    English                 9         74
# 2           2    Teacher_2    English                11         21
# 3           2    Teacher_2    English                11         96
# 4           5    Teacher_5    History                 6          1
#
#   course_name  credits semester
# 0   Course_66        4   Winter
# 1   Course_74        3   Summer
# 2   Course_21        4     Fall
# 3   Course_96        3   Summer
# 4    Course_1        4   Spring

# %% [markdown]
# ## Perform inner and left joins.

# %%
ij=pd.merge(t,c,on='teacher_id',how='inner')
ij.head()
# Out:
#    teacher_id teacher_name department  experience_years  course_id  \
# 0           1    Teacher_1    English                 9         66
# 1           1    Teacher_1    English                 9         74
# 2           2    Teacher_2    English                11         21
# 3           2    Teacher_2    English                11         96
# 4           5    Teacher_5    History                 6          1
#
#   course_name  credits semester
# 0   Course_66        4   Winter
# 1   Course_74        3   Summer
# 2   Course_21        4     Fall
# 3   Course_96        3   Summer
# 4    Course_1        4   Spring

# %%
oj=pd.merge(t,c,on='teacher_id',how='left')
oj.head()
# Out:
#    teacher_id teacher_name department  experience_years  course_id  \
# 0           1    Teacher_1    English                 9       66.0
# 1           1    Teacher_1    English                 9       74.0
# 2           2    Teacher_2    English                11       21.0
# 3           2    Teacher_2    English                11       96.0
# 4           3    Teacher_3    English                15        NaN
#
#   course_name  credits semester
# 0   Course_66      4.0   Winter
# 1   Course_74      3.0   Summer
# 2   Course_21      4.0     Fall
# 3   Course_96      3.0   Summer
# 4         NaN      NaN      NaN

# %% [markdown]
# ## • Compute average courses per teacher.

# %%
average=merge.groupby('teacher_id')['course_id'].count().mean()
print("Average courses per teacher:",average)
# Out:
# Average courses per teacher: 1.694915254237288

# %% [markdown]
# ## Group by department and calculate total workload

# %%
workload=merge.groupby('department')['course_id'].count().sum()
print("Total workload:",workload)
# Out:
# Total workload: 100
